# %% [markdown]
# ### Data Exploration

# %%
import pandas as pd

df = pd.read_csv("/content/Iris.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
# starting 5 rows of your data
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# last 5 rows of your data
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
# information about your data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
#coloumn of your data
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
#stats of the data
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# The Iris dataset consists of 150 records with 6 features: Id, SepalLengthCm, SepalWidthCm, PetalLengthCm, PetalWidthCm, and Species. It is a balanced dataset with three species of iris flowers—Iris-setosa, Iris-versicolor, and Iris-virginica—each represented by 50 samples. All the data types are appropriate, with numeric types for measurements and a categorical type for species. There are no missing values in the dataset, indicating clean and complete data. The statistical summary shows that petal length and width vary significantly across species, making them more useful for classification than sepal measurements. Sepal lengths range from 4.3 to 7.9 cm, while petal lengths range from 1.0 to 6.9 cm, showing greater variation. The dataset is widely used in machine learning for demonstrating classification algorithms due to its simplicity, balanced class distribution, and clearly separable feature patterns, especially in the petal dimensions.

# %% [markdown]
# #### Data Cleaning

# %% [markdown]
# 3 steps : Missing values, Duplicate values, Inconsistent values

# %% [markdown]
# ### Missing Values

# %%
df.dropna(inplace= True)
df = df.dropna()

# %% [markdown]
# #### Categorical Variables EDA

# %%
df['Species']
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object

# %%
df['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
df.Species.value_counts(normalize = True)
# Out:
# Species
# Iris-setosa        0.333333
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# Name: proportion, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
#distribution
import matplotlib.pyplot as plt
df.Species.value_counts(normalize = True).plot(kind='bar')
plt.title("value counts of the Species variable")
plt.xlabel("Specie Type")
plt.xticks(rotation=0)
plt.ylabel("count")
plt.show()

# %% [markdown]
# #### scatterplot

# %%
sns.pairplot(df, hue = "Species")

# %%
sns.pairplot(df, hue = "Species")

# %%
import seaborn as sns

# %%
sns.pairplot(df)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Species'] = le.fit_transform(df['Species'])
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1            5.1           3.5            1.4           0.2        0
# 1      2            4.9           3.0            1.4           0.2        0
# 2      3            4.7           3.2            1.3           0.2        0
# 3      4            4.6           3.1            1.5           0.2        0
# 4      5            5.0           3.6            1.4           0.2        0
# ..   ...            ...           ...            ...           ...      ...
# 145  146            6.7           3.0            5.2           2.3        2
# 146  147            6.3           2.5            5.0           1.9        2
# 147  148            6.5           3.0            5.2           2.0        2
# 148  149            6.2           3.4            5.4           2.3        2
# 149  150            5.9           3.0            5.1           1.8        2
#
# [150 rows x 6 columns]

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5            1.4           0.2        0
# 1   2            4.9           3.0            1.4           0.2        0
# 2   3            4.7           3.2            1.3           0.2        0
# 3   4            4.6           3.1            1.5           0.2        0
# 4   5            5.0           3.6            1.4           0.2        0

# %%
import seaborn as sns
sns.scatterplot( x="SepalLengthCm", y="SepalWidthCm", hue="Species", data=df, palette="Dark2",s=80)
plt.title("Scatterplot of SepalLengthCm vs SepalWidthCm")
plt.show()

# %%
import seaborn as sns
sns.scatterplot( x="PetalLengthCm", y="PetalWidthCm", hue="Species", data=df, palette="Dark2",s=80)
plt.title("Scatterplot of Petal Length and Petal Width")
plt.show()

# %% [markdown]
# #### Correlation Heatmap

# %%
df['Species']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: Species, Length: 150, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Species'] = le.fit_transform(df['Species'])
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1132424681.py in <cell line: 0>()
#       1 from sklearn.preprocessing import LabelEncoder
#       2 le = LabelEncoder()
# ----> 3 df['Species'] = le.fit_transform(df['Species'])
#       4 df
#
# NameError: name 'df' is not defined

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    int64
# dtypes: float64(4), int64(2)
# memory usage: 7.2 KB

# %%
df1 = df[['Id','SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]
df1
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
# [150 rows x 5 columns]

# %%
# Correlation heatmap
plt.figure(figsize=(10,10))
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='Pastel2')
plt.title('Correlatation Matrix of Iris dataset')
plt.show()

# %%
Y = df['Species']
X = df.drop(columns = ['Id','Species'])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, train_size = 0.80)

# %%
X_test.shape
# Out:
# (30, 4)

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
#Training
model.fit(X_train, Y_train)

# Testing
y_pred = model.predict(X_test)

#Compare
from sklearn.metrics import accuracy_score
score = accuracy_score(Y_test, y_pred)
accuracy = score*100
print(accuracy)
# Out:
# 93.33333333333333

# %%
from sklearn.metrics import confusion_matrix

#print the confusion matrix
print("Confusion Matrix")
cm = confusion_matrix(Y_test, y_pred)
print(cm)
# Out:
# Confusion Matrix
# [[ 9  0  0]
#  [ 0 11  1]
#  [ 0  1  8]]

# %%
plt.figure(figsize = (6, 4))
sns.heatmap(cm,annot = True, fmt = 'd', cmap = 'Blues', cbar = False)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# %%
from sklearn.metrics import classification_report
# Generate classification report
report = classification_report(Y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         9
#            1       0.92      0.92      0.92        12
#            2       0.89      0.89      0.89         9
#
#     accuracy                           0.93        30
#    macro avg       0.94      0.94      0.94        30
# weighted avg       0.93      0.93      0.93        30

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier()
clf.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = clf.predict(X_test)
score = accuracy_score(Y_test, y_pred)
accuracy = score*100
print(accuracy)
# Out:
# 96.66666666666667

# %%
from sklearn.metrics import confusion_matrix
y_pred = clf.predict(X_test)

#print the confusion matrix
print("Confusion Matrix")
cm = confusion_matrix(Y_test, y_pred)
print(cm)
# Out:
# Confusion Matrix
# [[ 9  0  0]
#  [ 0 11  1]
#  [ 0  0  9]]

# %%
# Heatmap
plt.figure(figsize=(10,10))
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='Pastel2')
plt.title('Correlatation Matrix of Iris dataset')
plt.show()

# %%
plt.figure(figsize = (6, 4))
sns.heatmap(cm,annot = True, fmt = 'd', cmap = 'Blues', cbar = False)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# %%
from sklearn.metrics import classification_report
# Generate classification report
report = classification_report(Y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         9
#            1       1.00      0.92      0.96        12
#            2       0.90      1.00      0.95         9
#
#     accuracy                           0.97        30
#    macro avg       0.97      0.97      0.97        30
# weighted avg       0.97      0.97      0.97        30

# %% [markdown]
# # Gaussian NB

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()
nb.fit(X_train, Y_train)
# Out:
# GaussianNB()

# %%
y_pred = nb.predict(X_test)
score = accuracy_score(Y_test, y_pred)
accuracy = score*100
print(accuracy)
# Out:
# 96.66666666666667

# %%
plt.figure(figsize = (6, 4))
sns.heatmap(cm,annot = True, fmt = 'd', cmap = 'Blues', cbar = False)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# %%
from sklearn.metrics import classification_report
# Generate classification report
report = classification_report(Y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         9
#            1       0.92      1.00      0.96        12
#            2       1.00      0.89      0.94         9
#
#     accuracy                           0.97        30
#    macro avg       0.97      0.96      0.97        30
# weighted avg       0.97      0.97      0.97        30

# %% [markdown]
# # SVC

# %%
from sklearn.svm import SVC
sfc = SVC()
sfc.fit(X_train, Y_train)
# Out:
# SVC()

# %%
y_pred = sfc.predict(X_test)
score = accuracy_score(Y_test, y_pred)
accuracy = score*100
print(accuracy)
# Out:
# 93.33333333333333

# %%
from sklearn.metrics import confusion_matrix
y_pred = sfc.predict(X_test)

#print the confusion matrix
print("Confusion Matrix")
cm = confusion_matrix(Y_test, y_pred)
print(cm)
# Out:
# Confusion Matrix
# [[ 9  0  0]
#  [ 0 11  1]
#  [ 0  1  8]]

# %%
plt.figure(figsize = (6, 4))
sns.heatmap(cm,annot = True, fmt = 'd', cmap = 'Blues', cbar = False)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# %%
from sklearn.metrics import classification_report
# Generate classification report
report = classification_report(Y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         9
#            1       0.92      0.92      0.92        12
#            2       0.89      0.89      0.89         9
#
#     accuracy                           0.93        30
#    macro avg       0.94      0.94      0.94        30
# weighted avg       0.93      0.93      0.93        30

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators = 10, criterion = 'entropy')
classifier.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10)

# %%
y_pred = classifier.predict(X_test)
score = accuracy_score(Y_test, y_pred)
accuracy = score*100
print(accuracy)
# Out:
# 90.0

# %%
plt.figure(figsize = (6, 4))
sns.heatmap(cm,annot = True, fmt = 'd', cmap = 'Blues', cbar = False)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# %%
from sklearn.metrics import classification_report
# Generate classification report
report = classification_report(Y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         9
#            1       0.85      0.92      0.88        12
#            2       0.88      0.78      0.82         9
#
#     accuracy                           0.90        30
#    macro avg       0.91      0.90      0.90        30
# weighted avg       0.90      0.90      0.90        30
